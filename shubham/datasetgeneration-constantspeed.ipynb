# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from dataclasses import dataclass
from typing import List, Tuple, Dict
import json
import shutil
import matplotlib.gridspec as gridspec
import io
from PIL import Image
from IPython.display import Image as IPImage
import torch
from PIL import Image as PILImage
from matplotlib.animation import FuncAnimation
from IPython.display import display, HTML
import ipywidgets as widgets
from IPython.display import display, IFrame
from matplotlib.animation import HTMLWriter
from matplotlib.patches import Circle

# %%
class Entity:
    def __init__(self, x, y, entity_type, direction=None):
        self.x = x
        self.y = y
        self.type = entity_type
        # direction is a tuple (dx, dy) representing movement direction
        self.direction = direction if direction is not None else (0, 0)

    def move(self):
        self.x += self.direction[0]
        self.y += self.direction[1]
        
    def reverse_direction(self):
        """Reverse the direction by changing signs of dx and dy"""
        self.direction = (-self.direction[0], -self.direction[1])

def detect_collision(entities):
    collisions = []
    for i in range(len(entities)):
        for j in range(i+1, len(entities)):
            if entities[i].x == entities[j].x and entities[i].y == entities[j].y:
                collisions.append((entities[i], entities[j]))
    return collisions

# %%
class SyntheticDataGenerator:
    def __init__(self, grid_size=10, num_vehicles=5, num_pedestrians=5, num_obstacles=5):
        self.grid_size = grid_size
        self.num_vehicles = num_vehicles
        self.num_pedestrians = num_pedestrians
        self.num_obstacles = num_obstacles

    def get_horizontal_direction(self):
        """Returns a random horizontal direction"""
        return (np.random.choice([-1, 1]), 0)

    def get_vertical_direction(self):
        """Returns a random vertical direction"""
        return (0, np.random.choice([-1, 1]))

    def will_hit_edge(self, x, y):
        """Check if next position would be at or beyond grid edge"""
        return (x <= 0 or x >= self.grid_size - 1 or 
                y <= 0 or y >= self.grid_size - 1)

    def get_safe_obstacle_position(self, pedestrians, occupied_positions):
        """
        Get a safe position for an obstacle that won't interfere with pedestrian paths
        pedestrians: list of tuples (position, direction)
        occupied_positions: set of (x, y) positions already taken
        """
        max_attempts = 100000
        attempts = 0
        
        while attempts < max_attempts:
            x = np.random.randint(0, self.grid_size)
            y = np.random.randint(0, self.grid_size)
            position = (x, y)
            
            if position in occupied_positions:
                attempts += 1
                continue
                
            # Check if position is safe for all pedestrians
            is_safe = True
            for ped_pos, ped_dir in pedestrians:
                # If pedestrian moves vertically (dx=0), obstacle can't have same x-coordinate
                if ped_dir[0] == 0:  # Vertical movement
                    if x == ped_pos[0]:
                        is_safe = False
                        break
                # If pedestrian moves horizontally (dy=0), obstacle can't have same y-coordinate
                elif ped_dir[1] == 0:  # Horizontal movement
                    if y == ped_pos[1]:
                        is_safe = False
                        break
            
            if is_safe:
                return (x, y)
            
            attempts += 1
            
        # If we couldn't find a safe position, try one last time without checking pedestrian paths
        while True:
            x = np.random.randint(0, self.grid_size)
            y = np.random.randint(0, self.grid_size)
            position = (x, y)
            if position not in occupied_positions:
                return position

    def generate_data(self, num_samples=100, num_steps=10):
        data = []
        for _ in range(num_samples):
            scenario = []
            entities = []
            occupied_positions = set()
            
            # First, place and set up pedestrians
            pedestrian_info = []  # Store pedestrian positions and directions
            vehicles_horizontal = np.random.choice([True, False])
            
            for _ in range(self.num_pedestrians):
                while True:
                    x, y = np.random.randint(0, self.grid_size, size=2)
                    if (x, y) not in occupied_positions:
                        break
                
                # Direction perpendicular to vehicles
                direction = self.get_horizontal_direction() if not vehicles_horizontal else self.get_vertical_direction()
                pedestrian_info.append(((x, y), direction))
                occupied_positions.add((x, y))
                entities.append(Entity(x, y, 'pedestrian', direction))
            
            # Then place vehicles
            for _ in range(self.num_vehicles):
                while True:
                    x, y = np.random.randint(0, self.grid_size, size=2)
                    if (x, y) not in occupied_positions:
                        break
                
                direction = self.get_horizontal_direction() if vehicles_horizontal else self.get_vertical_direction()
                occupied_positions.add((x, y))
                entities.append(Entity(x, y, 'vehicle', direction))
            
            # Finally, place obstacles in safe positions
            for _ in range(self.num_obstacles):
                x, y = self.get_safe_obstacle_position(pedestrian_info, occupied_positions)
                occupied_positions.add((x, y))
                entities.append(Entity(x, y, 'obstacle', (0, 0)))
            
            scenario.append(entities.copy())
            
            # Generate movements for subsequent steps
            for _ in range(num_steps - 1):
                new_entities = []
                for entity in entities:
                    # Create new entity instance with same properties
                    new_entity = Entity(entity.x, entity.y, entity.type, entity.direction)
                    
                    if new_entity.type != 'obstacle':
                        # Check if next position would hit edge
                        next_x = new_entity.x + new_entity.direction[0]
                        next_y = new_entity.y + new_entity.direction[1]
                        
                        # If will hit edge, reverse direction
                        if self.will_hit_edge(next_x, next_y):
                            new_entity.reverse_direction()
                        
                        # Move in current direction (which might have just been reversed)
                        new_entity.move()
                    
                    new_entities.append(new_entity)
                
                scenario.append(new_entities)
                entities = new_entities
                
            data.append(scenario)
        return data

    def visualize_data(self, scenario, sample_id):
        # Create figure with adjusted size to accommodate legend
        fig = plt.figure(figsize=(8, 6))
        
        # Create gridspec to position the plot and legend
        gs = gridspec.GridSpec(1, 2, width_ratios=[4, 1])
        
        # Create main plot and legend axes
        ax = plt.subplot(gs[0])
        legend_ax = plt.subplot(gs[1])
        legend_ax.axis('off')  # Hide the legend axes frame
        
        # Dictionary to store frame-specific collision locations
        collision_data = {}
        
        # Pre-compute collision frames and locations
        for frame, entities in enumerate(scenario):
            collisions = detect_collision(entities)
            if collisions:
                # Store only the exact collision locations for this frame
                collision_data[frame] = [(entity1.x, entity1.y) for entity1, entity2 in collisions]

        def update(frame):
            ax.clear()
            legend_ax.clear()
            legend_ax.axis('off')

            entities = scenario[frame]

            # Create empty lists for legend handles and labels
            legend_elements = []

            # Draw entities and collect unique elements for legend
            vehicles = ax.scatter([], [], color='blue', marker='^', s=200, label='Vehicle')
            pedestrians = ax.scatter([], [], color='red', marker='o', s=200, label='Pedestrian')
            obstacles = ax.scatter([], [], color='green', marker='s', s=200, label='Obstacle')

            # Add to legend elements
            legend_elements.extend([vehicles, pedestrians, obstacles])

            # Draw actual entities and their direction indicators
            for entity in entities:
                if entity.type == 'vehicle':
                    ax.scatter(entity.x, entity.y, color='blue', marker='^', s=200)
                    # Add direction indicator
                    if entity.direction != (0, 0):
                        ax.arrow(entity.x, entity.y, 
                               entity.direction[0] * 0.3, entity.direction[1] * 0.3,
                               head_width=0.1, head_length=0.1, fc='blue', ec='blue')
                elif entity.type == 'pedestrian':
                    ax.scatter(entity.x, entity.y, color='red', marker='o', s=200)
                    # Add direction indicator
                    if entity.direction != (0, 0):
                        ax.arrow(entity.x, entity.y, 
                               entity.direction[0] * 0.3, entity.direction[1] * 0.3,
                               head_width=0.1, head_length=0.1, fc='red', ec='red')
                else:
                    ax.scatter(entity.x, entity.y, color='green', marker='s', s=200)

            # Draw collision circles only at exact collision locations
            if frame in collision_data:
                for x, y in collision_data[frame]:
                    circle = Circle((x, y), radius=1, color='red', alpha=0.3)
                    ax.add_patch(circle)
                ax.text(0.02, 0.98, 'COLLISION!', transform=ax.transAxes, 
                       color='red', fontsize=12, verticalalignment='top')
                # Add collision indicator to legend
                collision_patch = plt.scatter([], [], c='red', alpha=0.3, marker='o', s=500, label='Collision Area')
                legend_elements.append(collision_patch)

            # Set up the main plot with explicit grid lines and labels
            ax.set_xlim(-0.5, self.grid_size - 0.5)
            ax.set_ylim(-0.5, self.grid_size - 0.5)
            ax.set_title(f"Time Step {frame+1}")

            # Set major ticks at integer positions
            ax.set_xticks(range(self.grid_size))
            ax.set_yticks(range(self.grid_size))

            # Add grid with integer spacing
            ax.grid(True, which='major', linestyle='-', linewidth=1)

            # Add minor gridlines at 0.5 intervals if desired
            ax.grid(True, which='minor', linestyle=':', linewidth=0.5)

            # Set labels for axes
            ax.set_xlabel('X Coordinate')
            ax.set_ylabel('Y Coordinate')

            # Create legend in the separate axis
            legend_ax.legend(handles=legend_elements, 
                           labels=['Vehicle', 'Pedestrian', 'Obstacle', 'Collision Area'] if frame in collision_data 
                           else ['Vehicle', 'Pedestrian', 'Obstacle'],
                           loc='center left',
                           bbox_to_anchor=(0, 0.5))

            # Adjust layout to prevent overlap
            plt.tight_layout()

        ani = FuncAnimation(fig, update, frames=len(scenario), interval=500, repeat=False)

        # Create the animations folder if it doesn't exist
        os.makedirs('animations', exist_ok=True)

        # Save the animation as an HTML file
        html_path = f'animations/scenario_{sample_id}_perpendicular.html'
        writer = HTMLWriter(fps=2)
        ani.save(html_path, writer=writer)

        plt.close(fig)
        return html_path

    def analyze_collisions(self, scenario):
        collision_report = []
        for timestep, entities in enumerate(scenario):
            collisions = detect_collision(entities)
            if collisions:
                for entity1, entity2 in collisions:
                    collision_report.append({
                        'timestep': timestep + 1,
                        'location': (entity1.x, entity1.y),
                        'entities': (entity1.type, entity2.type)
                    })
        return collision_report

# %%
# Initialize the base generator
base_generator = SyntheticDataGenerator(grid_size=10, num_vehicles=1, num_pedestrians=1, num_obstacles=0)

# %%
data = base_generator.generate_data(num_samples=1, num_steps=100)

for i, scenario in enumerate(data):
    print(f"\nScenario {i+1}:")
    html_path = base_generator.visualize_data(scenario, sample_id=i+1)
    display(IFrame(src=html_path, width=800, height=800))

    # Get and display detailed collision report
    collision_report = base_generator.analyze_collisions(scenario)
    if collision_report:
        print("\nCollision Report:")
        for collision in collision_report:
            print(f"Time Step {collision['timestep']}: "
                  f"{collision['entities'][0].capitalize()} collided with "
                  f"{collision['entities'][1]} at position {collision['location']}")
    else:
        print("No collisions detected in this scenario")
    print("-" * 50)
# Out:
# Scenario 1:
#         <iframe
#             width="800"
#             height="800"
#             src="animations/scenario_1_perpendicular.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# No collisions detected in this scenario
# --------------------------------------------------

# %% [markdown]
# # Dataset Generation begins here

# %%
def convert_to_serializable(obj):
    """Convert numpy types to Python native types for JSON serialization"""
    if isinstance(obj, np.integer):
        return int(obj)
    elif isinstance(obj, np.floating):
        return float(obj)
    elif isinstance(obj, np.ndarray):
        return obj.tolist()
    elif isinstance(obj, tuple):
        return tuple(convert_to_serializable(item) for item in obj)
    elif isinstance(obj, list):
        return [convert_to_serializable(item) for item in obj]
    elif isinstance(obj, dict):
        return {key: convert_to_serializable(value) for key, value in obj.items()}
    return obj

@dataclass
class Sample:
    """Class to store information about a sequence of frames"""
    frames: List[List[Entity]]  # consecutive frames
    has_collision: bool
    collision_details: Dict = None  # Only for collision samples
    sample_id: int = None
    
    def set_id(self, new_id: int):
        """Set the sample ID"""
        self.sample_id = new_id
        return self

# %%
class GNNDatasetGenerator:
    def __init__(self, base_generator: SyntheticDataGenerator):
        self.generator = base_generator
        self.dataset_root = "traffic_dataset"
        self.collision_dir = os.path.join(self.dataset_root, "collision")
        self.no_collision_dir = os.path.join(self.dataset_root, "no_collision")
        self.metadata_path = os.path.join(self.dataset_root, "metadata.json")
        
    def setup_directories(self):
        """Create necessary directories and clean existing data"""
        if os.path.exists(self.dataset_root):
            shutil.rmtree(self.dataset_root)
        
        os.makedirs(self.dataset_root)
        os.makedirs(self.collision_dir)
        os.makedirs(self.no_collision_dir)

    def save_frame(self, entities: List[Entity], path: str, collision_location=None) -> None:
        """Save a single frame as an image with direction indicators and collision marking"""
        fig, ax = plt.subplots(figsize=(8, 8))
        
        # Plot each entity with direction indicators
        for entity in entities:
            if entity.type == 'vehicle':
                ax.scatter(entity.x, entity.y, color='blue', marker='^', s=200)
                if entity.direction != (0, 0):
                    ax.arrow(entity.x, entity.y, 
                           entity.direction[0] * 0.3, entity.direction[1] * 0.3,
                           head_width=0.1, head_length=0.1, fc='blue', ec='blue')
            elif entity.type == 'pedestrian':
                ax.scatter(entity.x, entity.y, color='red', marker='o', s=200)
                if entity.direction != (0, 0):
                    ax.arrow(entity.x, entity.y, 
                           entity.direction[0] * 0.3, entity.direction[1] * 0.3,
                           head_width=0.1, head_length=0.1, fc='red', ec='red')
            else:  # obstacle
                ax.scatter(entity.x, entity.y, color='green', marker='s', s=200)

        # Add collision circle if collision location is provided
        if collision_location:
            x, y = collision_location
            circle = Circle((x, y), radius=1, color='red', alpha=0.3)
            ax.add_patch(circle)
            ax.text(0.02, 0.98, 'COLLISION!', transform=ax.transAxes, 
                   color='red', fontsize=12, verticalalignment='top')
        
        # Set up the plot
        ax.set_xlim(-0.5, self.generator.grid_size - 0.5)
        ax.set_ylim(-0.5, self.generator.grid_size - 0.5)
        ax.grid(True)
        ax.set_xticks(range(self.generator.grid_size))
        ax.set_yticks(range(self.generator.grid_size))
        
        # Save and close
        plt.savefig(path)
        plt.close(fig)

    def check_sequence_validity(self, frames: List[List[Entity]], check_all: bool = False) -> bool:
        """
        Check if a sequence of frames is valid:
        - For collision samples (check_all=False): only last frame should have collision
        - For no-collision samples (check_all=True): no frame should have collision
        """
        for i, frame in enumerate(frames):
            has_collision = len(detect_collision(frame)) > 0
            if check_all and has_collision:
                return False
            elif not check_all and i < len(frames)-1 and has_collision:
                return False
            elif not check_all and i == len(frames)-1 and not has_collision:
                return False
        return True

    def extract_collision_samples(self, scenario: List[List[Entity]], window_size: int = 7) -> List[Sample]:
        """Extract valid collision samples from a scenario"""
        samples = []
        
        for i in range(window_size-1, len(scenario)):
            sequence = scenario[i-window_size+1:i+1]
            if self.check_sequence_validity(sequence, check_all=False):
                collisions = detect_collision(sequence[-1])
                collision_info = {
                    "frame": convert_to_serializable(i),
                    "collisions": [
                        {
                            "types": (c[0].type, c[1].type),
                            "location": (convert_to_serializable(c[0].x), 
                                       convert_to_serializable(c[0].y))
                        } for c in collisions
                    ]
                }
                samples.append(Sample(sequence, True, collision_info))
        
        return samples

    def extract_no_collision_samples(self, scenario: List[List[Entity]], window_size: int = 7) -> List[Sample]:
        """Extract valid no-collision samples from a scenario"""
        samples = []
        
        for i in range(window_size-1, len(scenario)):
            sequence = scenario[i-window_size+1:i+1]
            if self.check_sequence_validity(sequence, check_all=True):
                samples.append(Sample(sequence, False, None))
        
        return samples

    



    def get_scenario_hash(self, first_frame):
        """Create a hash of initial positions and directions to check for uniqueness"""
        positions = []
        for entity in first_frame:
            positions.append((entity.x, entity.y, entity.direction[0], entity.direction[1], entity.type))
        return tuple(sorted(positions))

    def generate_dataset(self, num_samples: int = 100, num_steps: int = 500, window_size: int = 7):
        """Generate complete dataset with balanced collision and no-collision samples"""
        self.setup_directories()
        
        collision_samples = []
        no_collision_samples = []
        samples_per_category = num_samples // 2
        #max_attempts = samples_per_category * 20  # Increased max attempts
        max_attempts = 100000
        attempts = 0
        
        # Keep track of used initial configurations
        used_configurations = set()
        
        while (len(collision_samples) < samples_per_category or 
               len(no_collision_samples) < samples_per_category) and attempts < max_attempts:
            attempts += 1
            
            # Randomize the seed for each generation
            np.random.seed(None)  # Reset the seed
            seed = np.random.randint(0, 1000000)
            np.random.seed(seed)
            
            # Create a new generator instance with randomized parameters
            current_generator = SyntheticDataGenerator(
                grid_size=self.generator.grid_size,
                num_vehicles=self.generator.num_vehicles,
                num_pedestrians=self.generator.num_pedestrians,
                num_obstacles=self.generator.num_obstacles
            )
            
            # Generate a single scenario
            scenario = current_generator.generate_data(num_samples=1, num_steps=num_steps)[0]
            
            # Check for collision samples if needed
            if len(collision_samples) < samples_per_category:
                new_samples = self.extract_collision_samples(scenario, window_size)
                for sample in new_samples:
                    if len(collision_samples) < samples_per_category:
                        # Check if this configuration was used before
                        config_hash = self.get_scenario_hash(sample.frames[0])
                        if config_hash not in used_configurations:
                            sample.set_id(len(collision_samples))
                            collision_samples.append(sample)
                            used_configurations.add(config_hash)
                            print(f"Found new collision sample: {len(collision_samples)}/{samples_per_category}")
            
            # Check for no-collision samples if needed
            if len(no_collision_samples) < samples_per_category:
                new_samples = self.extract_no_collision_samples(scenario, window_size)
                for sample in new_samples:
                    if len(no_collision_samples) < samples_per_category:
                        # Check if this configuration was used before
                        config_hash = self.get_scenario_hash(sample.frames[0])
                        if config_hash not in used_configurations:
                            sample.set_id(len(no_collision_samples))
                            no_collision_samples.append(sample)
                            used_configurations.add(config_hash)
                            print(f"Found new no-collision sample: {len(no_collision_samples)}/{samples_per_category}")
            
            # Print progress every 100 attempts
            if attempts % 100 == 0:
                print(f"Attempt {attempts}: Found {len(collision_samples)} collision and "
                      f"{len(no_collision_samples)} no-collision samples")
        
        if attempts >= max_attempts:
            print(f"Warning: Reached maximum attempts ({max_attempts}). "
                  f"Generated {len(collision_samples)} collision samples and "
                  f"{len(no_collision_samples)} no-collision samples.")
        
        # Save all samples
        print(f"Saving {len(collision_samples)} collision samples...")
        for sample in collision_samples:
            self.save_sample(sample)
            
        print(f"Saving {len(no_collision_samples)} no-collision samples...")
        for sample in no_collision_samples:
            self.save_sample(sample)
        
        # Save global metadata
        global_metadata = {
            "total_samples": convert_to_serializable(len(collision_samples) + len(no_collision_samples)),
            "collision_samples": convert_to_serializable(len(collision_samples)),
            "no_collision_samples": convert_to_serializable(len(no_collision_samples)),
            "window_size": convert_to_serializable(window_size),
            "grid_size": convert_to_serializable(self.generator.grid_size),
            "num_vehicles": convert_to_serializable(self.generator.num_vehicles),
            "num_pedestrians": convert_to_serializable(self.generator.num_pedestrians),
            "num_obstacles": convert_to_serializable(self.generator.num_obstacles),
            "unique_configurations": convert_to_serializable(len(used_configurations))
        }
        
        with open(self.metadata_path, 'w') as f:
            json.dump(global_metadata, f, indent=2)
            
        print("Dataset generation completed!")

    def save_sample(self, sample: Sample):
        """Save a sample's frames and metadata"""
        if sample.sample_id is None:
            raise ValueError("Sample ID must be set before saving")
            
        # Determine target directory
        base_dir = self.collision_dir if sample.has_collision else self.no_collision_dir
        sample_dir = os.path.join(base_dir, f"sample_{sample.sample_id:05d}")
        os.makedirs(sample_dir)
        
        # Save frames
        for i, frame in enumerate(sample.frames):
            frame_path = os.path.join(sample_dir, f"frame_{i:02d}.png")
            
            # Get collision location for the last frame if it's a collision sample
            collision_location = None
            if sample.has_collision and i == len(sample.frames) - 1 and sample.collision_details:
                collision_location = sample.collision_details["collisions"][0]["location"]
                
            self.save_frame(frame, frame_path, collision_location)
        
        # Save initial configuration details
        initial_config = {
            "sample_id": convert_to_serializable(sample.sample_id),
            "has_collision": sample.has_collision,
            "collision_details": convert_to_serializable(sample.collision_details),
            "initial_positions": [
                {
                    "type": entity.type,
                    "position": (convert_to_serializable(entity.x), convert_to_serializable(entity.y)),
                    "direction": (convert_to_serializable(entity.direction[0]), 
                                convert_to_serializable(entity.direction[1]))
                }
                for entity in sample.frames[0]
            ]
        }
        
        with open(os.path.join(sample_dir, "metadata.json"), 'w') as f:
            json.dump(initial_config, f, indent=2)

# %%
# Initialize the base generator with desired parameters
base_generator = SyntheticDataGenerator(
    grid_size=10,
    num_vehicles=1,
    num_pedestrians=1,
    num_obstacles=0
)

# Create the GNN dataset generator
dataset_generator = GNNDatasetGenerator(base_generator)

# Generate the dataset
dataset_generator.generate_dataset(
    num_samples=1000,
    num_steps=500,
    window_size=7
)
# Out:
# Found new no-collision sample: 1/500
# Found new no-collision sample: 2/500
# Found new no-collision sample: 3/500
# Found new no-collision sample: 4/500
# Found new no-collision sample: 5/500
# Found new no-collision sample: 6/500
# Found new no-collision sample: 7/500
# Found new no-collision sample: 8/500
# Found new no-collision sample: 9/500
# Found new no-collision sample: 10/500
# Found new no-collision sample: 11/500
# Found new no-collision sample: 12/500
# Found new no-collision sample: 13/500
# Found new no-collision sample: 14/500
# Found new collision sample: 1/500
# Found new no-collision sample: 15/500
# Found new no-collision sample: 16/500
# Found new no-collision sample: 17/500
# Found new no-collision sample: 18/500
# Found new no-collision sample: 19/500
# Found new no-collision sample: 20/500
# Found new no-collision sample: 21/500
# Found new no-collision sample: 22/500
# Found new no-collision sample: 23/500
# Found new no-collision sample: 24/500
# Found new no-collision sample: 25/500
# Found new no-collision sample: 26/500
# Found new no-collision sample: 27/500
# Found new no-collision sample: 28/500
# Found new no-collision sample: 29/500
# Found new no-collision sample: 30/500
# Found new no-collision sample: 31/500
# Found new no-collision sample: 32/500
# Found new no-collision sample: 33/500
# Found new no-collision sample: 34/500
# Found new no-collision sample: 35/500
# Found new no-collision sample: 36/500
# Found new no-collision sample: 37/500
# Found new no-collision sample: 38/500
# Found new no-collision sample: 39/500
# Found new no-collision sample: 40/500
# Found new no-collision sample: 41/500
# Found new no-collision sample: 42/500
# Found new no-collision sample: 43/500
# Found new no-collision sample: 44/500
# Found new no-collision sample: 45/500
# Found new no-collision sample: 46/500
# Found new no-collision sample: 47/500
# Found new no-collision sample: 48/500
# Found new no-collision sample: 49/500
# Found new no-collision sample: 50/500
# Found new no-collision sample: 51/500
# Found new no-collision sample: 52/500
# Found new no-collision sample: 53/500
# Found new no-collision sample: 54/500
# Found new no-collision sample: 55/500
# Found new no-collision sample: 56/500
# Found new no-collision sample: 57/500
# Found new no-collision sample: 58/500
# Found new no-collision sample: 59/500
# Found new no-collision sample: 60/500
# Found new no-collision sample: 61/500
# Found new no-collision sample: 62/500
# Found new no-collision sample: 63/500
# Found new no-collision sample: 64/500
# Found new no-collision sample: 65/500
# Found new no-collision sample: 66/500
# Found new no-collision sample: 67/500
# Found new no-collision sample: 68/500
# Found new no-collision sample: 69/500
# Found new no-collision sample: 70/500
# Found new no-collision sample: 71/500
# Found new no-collision sample: 72/500
# Found new no-collision sample: 73/500
# Found new no-collision sample: 74/500
# Found new no-collision sample: 75/500
# Found new no-collision sample: 76/500
# Found new no-collision sample: 77/500
# Found new no-collision sample: 78/500
# Found new no-collision sample: 79/500
# Found new no-collision sample: 80/500
# Found new no-collision sample: 81/500
# Found new no-collision sample: 82/500
# Found new no-collision sample: 83/500
# Found new no-collision sample: 84/500
# Found new no-collision sample: 85/500
# Found new no-collision sample: 86/500
# Found new no-collision sample: 87/500
# Found new no-collision sample: 88/500
# Found new no-collision sample: 89/500
# Found new no-collision sample: 90/500
# Found new no-collision sample: 91/500
# Found new no-collision sample: 92/500
# Found new no-collision sample: 93/500
# Found new no-collision sample: 94/500
# Found new no-collision sample: 95/500
# Found new no-collision sample: 96/500
# Found new no-collision sample: 97/500
# Found new no-collision sample: 98/500
# Found new no-collision sample: 99/500
# Found new no-collision sample: 100/500
# Found new no-collision sample: 101/500
# Found new no-collision sample: 102/500
# Found new no-collision sample: 103/500
# Found new no-collision sample: 104/500
# Found new no-collision sample: 105/500
# Found new no-collision sample: 106/500
# Found new no-collision sample: 107/500
# Found new no-collision sample: 108/500
# Found new no-collision sample: 109/500
# Found new no-collision sample: 110/500
# Found new no-collision sample: 111/500
# Found new no-collision sample: 112/500
# Found new no-collision sample: 113/500
# Found new no-collision sample: 114/500
# Found new no-collision sample: 115/500
# Found new no-collision sample: 116/500
# Found new no-collision sample: 117/500
# Found new no-collision sample: 118/500
# Found new no-collision sample: 119/500
# Found new no-collision sample: 120/500
# Found new no-collision sample: 121/500
# Found new no-collision sample: 122/500
# Found new no-collision sample: 123/500
# Found new no-collision sample: 124/500
# Found new no-collision sample: 125/500
# Found new no-collision sample: 126/500
# Found new no-collision sample: 127/500
# Found new no-collision sample: 128/500
# Found new no-collision sample: 129/500
# Found new no-collision sample: 130/500
# Found new no-collision sample: 131/500
# Found new no-collision sample: 132/500
# Found new no-collision sample: 133/500
# Found new no-collision sample: 134/500
# Found new no-collision sample: 135/500
# Found new no-collision sample: 136/500
# Found new no-collision sample: 137/500
# Found new no-collision sample: 138/500
# Found new no-collision sample: 139/500
# Found new no-collision sample: 140/500
# Found new no-collision sample: 141/500
# Found new no-collision sample: 142/500
# Found new no-collision sample: 143/500
# Found new no-collision sample: 144/500
# Found new no-collision sample: 145/500
# Found new no-collision sample: 146/500
# Found new no-collision sample: 147/500
# Found new no-collision sample: 148/500
# Found new no-collision sample: 149/500
# Found new no-collision sample: 150/500
# Found new no-collision sample: 151/500
# Found new no-collision sample: 152/500
# Found new no-collision sample: 153/500
# Found new no-collision sample: 154/500
# Found new no-collision sample: 155/500
# Found new no-collision sample: 156/500
# Found new collision sample: 2/500
# Found new no-collision sample: 157/500
# Found new no-collision sample: 158/500
# Found new no-collision sample: 159/500
# Found new no-collision sample: 160/500
# Found new no-collision sample: 161/500
# Found new no-collision sample: 162/500
# Found new no-collision sample: 163/500
# Found new no-collision sample: 164/500
# Found new no-collision sample: 165/500
# Found new no-collision sample: 166/500
# Found new no-collision sample: 167/500
# Found new no-collision sample: 168/500
# Found new no-collision sample: 169/500
# Found new no-collision sample: 170/500
# Found new no-collision sample: 171/500
# Found new no-collision sample: 172/500
# Found new no-collision sample: 173/500
# Found new no-collision sample: 174/500
# Found new no-collision sample: 175/500
# Found new no-collision sample: 176/500
# Found new no-collision sample: 177/500
# Found new no-collision sample: 178/500
# Found new no-collision sample: 179/500
# Found new no-collision sample: 180/500
# Found new no-collision sample: 181/500
# Found new no-collision sample: 182/500
# Found new no-collision sample: 183/500
# Found new no-collision sample: 184/500
# Found new no-collision sample: 185/500
# Found new no-collision sample: 186/500
# Found new no-collision sample: 187/500
# Found new no-collision sample: 188/500
# Found new no-collision sample: 189/500
# Found new no-collision sample: 190/500
# Found new no-collision sample: 191/500
# Found new no-collision sample: 192/500
# Found new no-collision sample: 193/500
# Found new no-collision sample: 194/500
# Found new no-collision sample: 195/500
# Found new no-collision sample: 196/500
# Found new no-collision sample: 197/500
# Found new no-collision sample: 198/500
# Found new no-collision sample: 199/500
# Found new no-collision sample: 200/500
# Found new no-collision sample: 201/500
# Found new no-collision sample: 202/500
# Found new no-collision sample: 203/500
# Found new no-collision sample: 204/500
# Found new no-collision sample: 205/500
# Found new no-collision sample: 206/500
# Found new no-collision sample: 207/500
# Found new no-collision sample: 208/500
# Found new no-collision sample: 209/500
# Found new no-collision sample: 210/500
# Found new no-collision sample: 211/500
# Found new no-collision sample: 212/500
# Found new no-collision sample: 213/500
# Found new no-collision sample: 214/500
# Found new no-collision sample: 215/500
# Found new no-collision sample: 216/500
# Found new no-collision sample: 217/500
# Found new no-collision sample: 218/500
# Found new no-collision sample: 219/500
# Found new no-collision sample: 220/500
# Found new no-collision sample: 221/500
# Found new no-collision sample: 222/500
# Found new no-collision sample: 223/500
# Found new no-collision sample: 224/500
# Found new no-collision sample: 225/500
# Found new no-collision sample: 226/500
# Found new no-collision sample: 227/500
# Found new no-collision sample: 228/500
# Found new no-collision sample: 229/500
# Found new no-collision sample: 230/500
# Found new no-collision sample: 231/500
# Found new no-collision sample: 232/500
# Found new no-collision sample: 233/500
# Found new no-collision sample: 234/500
# Found new no-collision sample: 235/500
# Found new no-collision sample: 236/500
# Found new no-collision sample: 237/500
# Found new no-collision sample: 238/500
# Found new no-collision sample: 239/500
# Found new no-collision sample: 240/500
# Found new no-collision sample: 241/500
# Found new no-collision sample: 242/500
# Found new no-collision sample: 243/500
# Found new no-collision sample: 244/500
# Found new no-collision sample: 245/500
# Found new no-collision sample: 246/500
# Found new no-collision sample: 247/500
# Found new no-collision sample: 248/500
# Found new no-collision sample: 249/500
# Found new no-collision sample: 250/500
# Found new no-collision sample: 251/500
# Found new no-collision sample: 252/500
# Found new no-collision sample: 253/500
# Found new collision sample: 3/500
# Found new no-collision sample: 254/500
# Found new no-collision sample: 255/500
# Found new no-collision sample: 256/500
# Found new no-collision sample: 257/500
# Found new no-collision sample: 258/500
# Found new no-collision sample: 259/500
# Found new no-collision sample: 260/500
# Found new no-collision sample: 261/500
# Found new no-collision sample: 262/500
# Found new no-collision sample: 263/500
# Found new no-collision sample: 264/500
# Found new no-collision sample: 265/500
# Found new no-collision sample: 266/500
# Found new no-collision sample: 267/500
# Found new no-collision sample: 268/500
# Found new no-collision sample: 269/500
# Found new no-collision sample: 270/500
# Found new no-collision sample: 271/500
# Found new no-collision sample: 272/500
# Found new no-collision sample: 273/500
# Found new no-collision sample: 274/500
# Found new no-collision sample: 275/500
# Found new no-collision sample: 276/500
# Found new no-collision sample: 277/500
# Found new no-collision sample: 278/500
# Found new no-collision sample: 279/500
# Found new no-collision sample: 280/500
# Found new no-collision sample: 281/500
# Found new no-collision sample: 282/500
# Found new no-collision sample: 283/500
# Found new no-collision sample: 284/500
# Found new no-collision sample: 285/500
# Found new no-collision sample: 286/500
# Found new no-collision sample: 287/500
# Found new no-collision sample: 288/500
# Found new no-collision sample: 289/500
# Found new no-collision sample: 290/500
# Found new no-collision sample: 291/500
# Found new no-collision sample: 292/500
# Found new no-collision sample: 293/500
# Found new no-collision sample: 294/500
# Found new no-collision sample: 295/500
# Found new no-collision sample: 296/500
# Found new no-collision sample: 297/500
# Found new no-collision sample: 298/500
# Found new no-collision sample: 299/500
# Found new no-collision sample: 300/500
# Found new no-collision sample: 301/500
# Found new no-collision sample: 302/500
# Found new no-collision sample: 303/500
# Found new no-collision sample: 304/500
# Found new no-collision sample: 305/500
# Found new no-collision sample: 306/500
# Found new no-collision sample: 307/500
# Found new no-collision sample: 308/500
# Found new no-collision sample: 309/500
# Found new no-collision sample: 310/500
# Found new no-collision sample: 311/500
# Found new no-collision sample: 312/500
# Found new no-collision sample: 313/500
# Found new no-collision sample: 314/500
# Found new no-collision sample: 315/500
# Found new no-collision sample: 316/500
# Found new no-collision sample: 317/500
# Found new no-collision sample: 318/500
# Found new no-collision sample: 319/500
# Found new no-collision sample: 320/500
# Found new no-collision sample: 321/500
# Found new no-collision sample: 322/500
# Found new no-collision sample: 323/500
# Found new no-collision sample: 324/500
# Found new no-collision sample: 325/500
# Found new no-collision sample: 326/500
# Found new no-collision sample: 327/500
# Found new no-collision sample: 328/500
# Found new no-collision sample: 329/500
# Found new no-collision sample: 330/500
# Found new no-collision sample: 331/500
# Found new no-collision sample: 332/500
# Found new no-collision sample: 333/500
# Found new no-collision sample: 334/500
# Found new no-collision sample: 335/500
# Found new no-collision sample: 336/500
# Found new no-collision sample: 337/500
# Found new no-collision sample: 338/500
# Found new no-collision sample: 339/500
# Found new no-collision sample: 340/500
# Found new no-collision sample: 341/500
# Found new no-collision sample: 342/500
# Found new no-collision sample: 343/500
# Found new no-collision sample: 344/500
# Found new no-collision sample: 345/500
# Found new no-collision sample: 346/500
# Found new no-collision sample: 347/500
# Found new no-collision sample: 348/500
# Found new no-collision sample: 349/500
# Found new no-collision sample: 350/500
# Found new collision sample: 4/500
# Found new no-collision sample: 351/500
# Found new no-collision sample: 352/500
# Found new no-collision sample: 353/500
# Found new no-collision sample: 354/500
# Found new no-collision sample: 355/500
# Found new no-collision sample: 356/500
# Found new no-collision sample: 357/500
# Found new no-collision sample: 358/500
# Found new no-collision sample: 359/500
# Found new no-collision sample: 360/500
# Found new no-collision sample: 361/500
# Found new no-collision sample: 362/500
# Found new no-collision sample: 363/500
# Found new no-collision sample: 364/500
# Found new no-collision sample: 365/500
# Found new no-collision sample: 366/500
# Found new no-collision sample: 367/500
# Found new no-collision sample: 368/500
# Found new no-collision sample: 369/500
# Found new no-collision sample: 370/500
# Found new no-collision sample: 371/500
# Found new no-collision sample: 372/500
# Found new no-collision sample: 373/500
# Found new no-collision sample: 374/500
# Found new no-collision sample: 375/500
# Found new no-collision sample: 376/500
# Found new no-collision sample: 377/500
# Found new no-collision sample: 378/500
# Found new no-collision sample: 379/500
# Found new no-collision sample: 380/500
# Found new no-collision sample: 381/500
# Found new no-collision sample: 382/500
# Found new no-collision sample: 383/500
# Found new no-collision sample: 384/500
# Found new no-collision sample: 385/500
# Found new no-collision sample: 386/500
# Found new no-collision sample: 387/500
# Found new no-collision sample: 388/500
# Found new no-collision sample: 389/500
# Found new no-collision sample: 390/500
# Found new no-collision sample: 391/500
# Found new no-collision sample: 392/500
# Found new no-collision sample: 393/500
# Found new no-collision sample: 394/500
# Found new no-collision sample: 395/500
# Found new no-collision sample: 396/500
# Found new no-collision sample: 397/500
# Found new no-collision sample: 398/500
# Found new no-collision sample: 399/500
# Found new no-collision sample: 400/500
# Found new no-collision sample: 401/500
# Found new no-collision sample: 402/500
# Found new no-collision sample: 403/500
# Found new no-collision sample: 404/500
# Found new no-collision sample: 405/500
# Found new no-collision sample: 406/500
# Found new no-collision sample: 407/500
# Found new no-collision sample: 408/500
# Found new no-collision sample: 409/500
# Found new no-collision sample: 410/500
# Found new no-collision sample: 411/500
# Found new no-collision sample: 412/500
# Found new no-collision sample: 413/500
# Found new no-collision sample: 414/500
# Found new no-collision sample: 415/500
# Found new no-collision sample: 416/500
# Found new no-collision sample: 417/500
# Found new no-collision sample: 418/500
# Found new no-collision sample: 419/500
# Found new no-collision sample: 420/500
# Found new no-collision sample: 421/500
# Found new no-collision sample: 422/500
# Found new no-collision sample: 423/500
# Found new no-collision sample: 424/500
# Found new no-collision sample: 425/500
# Found new no-collision sample: 426/500
# Found new no-collision sample: 427/500
# Found new no-collision sample: 428/500
# Found new no-collision sample: 429/500
# Found new no-collision sample: 430/500
# Found new no-collision sample: 431/500
# Found new no-collision sample: 432/500
# Found new no-collision sample: 433/500
# Found new no-collision sample: 434/500
# Found new no-collision sample: 435/500
# Found new no-collision sample: 436/500
# Found new no-collision sample: 437/500
# Found new no-collision sample: 438/500
# Found new no-collision sample: 439/500
# Found new no-collision sample: 440/500
# Found new no-collision sample: 441/500
# Found new no-collision sample: 442/500
# Found new no-collision sample: 443/500
# Found new no-collision sample: 444/500
# Found new no-collision sample: 445/500
# Found new no-collision sample: 446/500
# Found new no-collision sample: 447/500
# Found new no-collision sample: 448/500
# Found new no-collision sample: 449/500
# Found new no-collision sample: 450/500
# Found new no-collision sample: 451/500
# Found new no-collision sample: 452/500
# Found new no-collision sample: 453/500
# Found new no-collision sample: 454/500
# Found new no-collision sample: 455/500
# Found new no-collision sample: 456/500
# Found new no-collision sample: 457/500
# Found new no-collision sample: 458/500
# Found new no-collision sample: 459/500
# Found new no-collision sample: 460/500
# Found new no-collision sample: 461/500
# Found new no-collision sample: 462/500
# Found new no-collision sample: 463/500
# Found new no-collision sample: 464/500
# Found new no-collision sample: 465/500
# Found new no-collision sample: 466/500
# Found new no-collision sample: 467/500
# Found new no-collision sample: 468/500
# Found new no-collision sample: 469/500
# Found new no-collision sample: 470/500
# Found new no-collision sample: 471/500
# Found new no-collision sample: 472/500
# Found new no-collision sample: 473/500
# Found new no-collision sample: 474/500
# Found new no-collision sample: 475/500
# Found new no-collision sample: 476/500
# Found new no-collision sample: 477/500
# Found new no-collision sample: 478/500
# Found new no-collision sample: 479/500
# Found new no-collision sample: 480/500
# Found new no-collision sample: 481/500
# Found new no-collision sample: 482/500
# Found new no-collision sample: 483/500
# Found new no-collision sample: 484/500
# Found new no-collision sample: 485/500
# Found new no-collision sample: 486/500
# Found new no-collision sample: 487/500
# Found new no-collision sample: 488/500
# Found new no-collision sample: 489/500
# Found new no-collision sample: 490/500
# Found new no-collision sample: 491/500
# Found new no-collision sample: 492/500
# Found new no-collision sample: 493/500
# Found new no-collision sample: 494/500
# Found new no-collision sample: 495/500
# Found new no-collision sample: 496/500
# Found new no-collision sample: 497/500
# Found new no-collision sample: 498/500
# Found new no-collision sample: 499/500
# Found new no-collision sample: 500/500
# Found new collision sample: 5/500
# Found new collision sample: 6/500
# Found new collision sample: 7/500
# Found new collision sample: 8/500
# Found new collision sample: 9/500
# Attempt 100: Found 9 collision and 500 no-collision samples
# Found new collision sample: 10/500
# Found new collision sample: 11/500
# Found new collision sample: 12/500
# Found new collision sample: 13/500
# Found new collision sample: 14/500
# Found new collision sample: 15/500
# Found new collision sample: 16/500
# Found new collision sample: 17/500
# Found new collision sample: 18/500
# Found new collision sample: 19/500
# Found new collision sample: 20/500
# Found new collision sample: 21/500
# Found new collision sample: 22/500
# Attempt 200: Found 22 collision and 500 no-collision samples
# Found new collision sample: 23/500
# Found new collision sample: 24/500
# Found new collision sample: 25/500
# Found new collision sample: 26/500
# Found new collision sample: 27/500
# Found new collision sample: 28/500
# Attempt 300: Found 28 collision and 500 no-collision samples
# Found new collision sample: 29/500
# Found new collision sample: 30/500
# Found new collision sample: 31/500
# Found new collision sample: 32/500
# Found new collision sample: 33/500
# Found new collision sample: 34/500
# Found new collision sample: 35/500
# Found new collision sample: 36/500
# Found new collision sample: 37/500
# Found new collision sample: 38/500
# Found new collision sample: 39/500
# Found new collision sample: 40/500
# Attempt 400: Found 40 collision and 500 no-collision samples
# Found new collision sample: 41/500
# Found new collision sample: 42/500
# Found new collision sample: 43/500
# Found new collision sample: 44/500
# Found new collision sample: 45/500
# Found new collision sample: 46/500
# Found new collision sample: 47/500
# Found new collision sample: 48/500
# Attempt 500: Found 48 collision and 500 no-collision samples
# Found new collision sample: 49/500
# Found new collision sample: 50/500
# Found new collision sample: 51/500
# Found new collision sample: 52/500
# Found new collision sample: 53/500
# Found new collision sample: 54/500
# Found new collision sample: 55/500
# Found new collision sample: 56/500
# Found new collision sample: 57/500
# Found new collision sample: 58/500
# Found new collision sample: 59/500
# Found new collision sample: 60/500
# Attempt 600: Found 60 collision and 500 no-collision samples
# Found new collision sample: 61/500
# Found new collision sample: 62/500
# Found new collision sample: 63/500
# Found new collision sample: 64/500
# Found new collision sample: 65/500
# Found new collision sample: 66/500
# Found new collision sample: 67/500
# Found new collision sample: 68/500
# Found new collision sample: 69/500
# Found new collision sample: 70/500
# Attempt 700: Found 70 collision and 500 no-collision samples
# Found new collision sample: 71/500
# Found new collision sample: 72/500
# Found new collision sample: 73/500
# Found new collision sample: 74/500
# Found new collision sample: 75/500
# Found new collision sample: 76/500
# Found new collision sample: 77/500
# Found new collision sample: 78/500
# Found new collision sample: 79/500
# Found new collision sample: 80/500
# Attempt 800: Found 80 collision and 500 no-collision samples
# Found new collision sample: 81/500
# Found new collision sample: 82/500
# Found new collision sample: 83/500
# Found new collision sample: 84/500
# Found new collision sample: 85/500
# Found new collision sample: 86/500
# Found new collision sample: 87/500
# Found new collision sample: 88/500
# Found new collision sample: 89/500
# Found new collision sample: 90/500
# Found new collision sample: 91/500
# Found new collision sample: 92/500
# Attempt 900: Found 92 collision and 500 no-collision samples
# Found new collision sample: 93/500
# Found new collision sample: 94/500
# Found new collision sample: 95/500
# Found new collision sample: 96/500
# Found new collision sample: 97/500
# Found new collision sample: 98/500
# Found new collision sample: 99/500
# Found new collision sample: 100/500
# Found new collision sample: 101/500
# Found new collision sample: 102/500
# Found new collision sample: 103/500
# Attempt 1000: Found 103 collision and 500 no-collision samples
# Found new collision sample: 104/500
# Found new collision sample: 105/500
# Found new collision sample: 106/500
# Found new collision sample: 107/500
# Found new collision sample: 108/500
# Found new collision sample: 109/500
# Found new collision sample: 110/500
# Found new collision sample: 111/500
# Found new collision sample: 112/500
# Attempt 1100: Found 112 collision and 500 no-collision samples
# Found new collision sample: 113/500
# Found new collision sample: 114/500
# Found new collision sample: 115/500
# Found new collision sample: 116/500
# Found new collision sample: 117/500
# Found new collision sample: 118/500
# Found new collision sample: 119/500
# Found new collision sample: 120/500
# Found new collision sample: 121/500
# Found new collision sample: 122/500
# Found new collision sample: 123/500
# Found new collision sample: 124/500
# Found new collision sample: 125/500
# Found new collision sample: 126/500
# Found new collision sample: 127/500
# Found new collision sample: 128/500
# Attempt 1200: Found 128 collision and 500 no-collision samples
# Found new collision sample: 129/500
# Found new collision sample: 130/500
# Found new collision sample: 131/500
# Found new collision sample: 132/500
# Found new collision sample: 133/500
# Found new collision sample: 134/500
# Found new collision sample: 135/500
# Found new collision sample: 136/500
# Found new collision sample: 137/500
# Found new collision sample: 138/500
# Found new collision sample: 139/500
# Attempt 1300: Found 139 collision and 500 no-collision samples
# Found new collision sample: 140/500
# Found new collision sample: 141/500
# Found new collision sample: 142/500
# Found new collision sample: 143/500
# Found new collision sample: 144/500
# Found new collision sample: 145/500
# Found new collision sample: 146/500
# Found new collision sample: 147/500
# Found new collision sample: 148/500
# Found new collision sample: 149/500
# Found new collision sample: 150/500
# Attempt 1400: Found 150 collision and 500 no-collision samples
# Found new collision sample: 151/500
# Found new collision sample: 152/500
# Found new collision sample: 153/500
# Found new collision sample: 154/500
# Found new collision sample: 155/500
# Found new collision sample: 156/500
# Found new collision sample: 157/500
# Found new collision sample: 158/500
# Found new collision sample: 159/500
# Found new collision sample: 160/500
# Found new collision sample: 161/500
# Found new collision sample: 162/500
# Attempt 1500: Found 162 collision and 500 no-collision samples
# Found new collision sample: 163/500
# Found new collision sample: 164/500
# Found new collision sample: 165/500
# Found new collision sample: 166/500
# Attempt 1600: Found 166 collision and 500 no-collision samples
# Found new collision sample: 167/500
# Found new collision sample: 168/500
# Found new collision sample: 169/500
# Found new collision sample: 170/500
# Found new collision sample: 171/500
# Found new collision sample: 172/500
# Found new collision sample: 173/500
# Found new collision sample: 174/500
# Found new collision sample: 175/500
# Found new collision sample: 176/500
# Attempt 1700: Found 176 collision and 500 no-collision samples
# Found new collision sample: 177/500
# Found new collision sample: 178/500
# Found new collision sample: 179/500
# Found new collision sample: 180/500
# Found new collision sample: 181/500
# Found new collision sample: 182/500
# Found new collision sample: 183/500
# Attempt 1800: Found 183 collision and 500 no-collision samples
# Found new collision sample: 184/500
# Found new collision sample: 185/500
# Found new collision sample: 186/500
# Found new collision sample: 187/500
# Found new collision sample: 188/500
# Found new collision sample: 189/500
# Attempt 1900: Found 189 collision and 500 no-collision samples
# Found new collision sample: 190/500
# Found new collision sample: 191/500
# Found new collision sample: 192/500
# Found new collision sample: 193/500
# Found new collision sample: 194/500
# Found new collision sample: 195/500
# Attempt 2000: Found 195 collision and 500 no-collision samples
# Found new collision sample: 196/500
# Found new collision sample: 197/500
# Found new collision sample: 198/500
# Found new collision sample: 199/500
# Found new collision sample: 200/500
# Found new collision sample: 201/500
# Attempt 2100: Found 201 collision and 500 no-collision samples
# Found new collision sample: 202/500
# Found new collision sample: 203/500
# Found new collision sample: 204/500
# Found new collision sample: 205/500
# Attempt 2200: Found 205 collision and 500 no-collision samples
# Found new collision sample: 206/500
# Found new collision sample: 207/500
# Found new collision sample: 208/500
# Found new collision sample: 209/500
# Found new collision sample: 210/500
# Found new collision sample: 211/500
# Found new collision sample: 212/500
# Attempt 2300: Found 212 collision and 500 no-collision samples
# Found new collision sample: 213/500
# Found new collision sample: 214/500
# Found new collision sample: 215/500
# Found new collision sample: 216/500
# Found new collision sample: 217/500
# Found new collision sample: 218/500
# Found new collision sample: 219/500
# Attempt 2400: Found 219 collision and 500 no-collision samples
# Found new collision sample: 220/500
# Found new collision sample: 221/500
# Found new collision sample: 222/500
# Found new collision sample: 223/500
# Attempt 2500: Found 223 collision and 500 no-collision samples
# Found new collision sample: 224/500
# Found new collision sample: 225/500
# Found new collision sample: 226/500
# Found new collision sample: 227/500
# Found new collision sample: 228/500
# Found new collision sample: 229/500
# Found new collision sample: 230/500
# Found new collision sample: 231/500
# Attempt 2600: Found 231 collision and 500 no-collision samples
# Found new collision sample: 232/500
# Found new collision sample: 233/500
# Found new collision sample: 234/500
# Found new collision sample: 235/500
# Found new collision sample: 236/500
# Found new collision sample: 237/500
# Found new collision sample: 238/500
# Attempt 2700: Found 238 collision and 500 no-collision samples
# Found new collision sample: 239/500
# Found new collision sample: 240/500
# Found new collision sample: 241/500
# Found new collision sample: 242/500
# Found new collision sample: 243/500
# Attempt 2800: Found 243 collision and 500 no-collision samples
# Found new collision sample: 244/500
# Found new collision sample: 245/500
# Found new collision sample: 246/500
# Found new collision sample: 247/500
# Found new collision sample: 248/500
# Found new collision sample: 249/500
# Attempt 2900: Found 249 collision and 500 no-collision samples
# Found new collision sample: 250/500
# Found new collision sample: 251/500
# Found new collision sample: 252/500
# Found new collision sample: 253/500
# Found new collision sample: 254/500
# Found new collision sample: 255/500
# Found new collision sample: 256/500
# Attempt 3000: Found 256 collision and 500 no-collision samples
# Found new collision sample: 257/500
# Found new collision sample: 258/500
# Found new collision sample: 259/500
# Found new collision sample: 260/500
# Attempt 3100: Found 260 collision and 500 no-collision samples
# Found new collision sample: 261/500
# Found new collision sample: 262/500
# Found new collision sample: 263/500
# Found new collision sample: 264/500
# Found new collision sample: 265/500
# Found new collision sample: 266/500
# Attempt 3200: Found 266 collision and 500 no-collision samples
# Found new collision sample: 267/500
# Found new collision sample: 268/500
# Found new collision sample: 269/500
# Attempt 3300: Found 269 collision and 500 no-collision samples
# Found new collision sample: 270/500
# Found new collision sample: 271/500
# Attempt 3400: Found 271 collision and 500 no-collision samples
# Found new collision sample: 272/500
# Found new collision sample: 273/500
# Found new collision sample: 274/500
# Found new collision sample: 275/500
# Found new collision sample: 276/500
# Found new collision sample: 277/500
# Found new collision sample: 278/500
# Found new collision sample: 279/500
# Attempt 3500: Found 279 collision and 500 no-collision samples
# Found new collision sample: 280/500
# Found new collision sample: 281/500
# Found new collision sample: 282/500
# Found new collision sample: 283/500
# Found new collision sample: 284/500
# Found new collision sample: 285/500
# Found new collision sample: 286/500
# Attempt 3600: Found 286 collision and 500 no-collision samples
# Found new collision sample: 287/500
# Found new collision sample: 288/500
# Found new collision sample: 289/500
# Found new collision sample: 290/500
# Found new collision sample: 291/500
# Found new collision sample: 292/500
# Attempt 3700: Found 292 collision and 500 no-collision samples
# Found new collision sample: 293/500
# Found new collision sample: 294/500
# Found new collision sample: 295/500
# Attempt 3800: Found 295 collision and 500 no-collision samples
# Found new collision sample: 296/500
# Found new collision sample: 297/500
# Found new collision sample: 298/500
# Attempt 3900: Found 298 collision and 500 no-collision samples
# Found new collision sample: 299/500
# Found new collision sample: 300/500
# Found new collision sample: 301/500
# Found new collision sample: 302/500
# Found new collision sample: 303/500
# Attempt 4000: Found 303 collision and 500 no-collision samples
# Found new collision sample: 304/500
# Found new collision sample: 305/500
# Attempt 4100: Found 305 collision and 500 no-collision samples
# Found new collision sample: 306/500
# Found new collision sample: 307/500
# Found new collision sample: 308/500
# Found new collision sample: 309/500
# Found new collision sample: 310/500
# Attempt 4200: Found 310 collision and 500 no-collision samples
# Found new collision sample: 311/500
# Found new collision sample: 312/500
# Found new collision sample: 313/500
# Attempt 4300: Found 313 collision and 500 no-collision samples
# Found new collision sample: 314/500
# Found new collision sample: 315/500
# Attempt 4400: Found 315 collision and 500 no-collision samples
# Found new collision sample: 316/500
# Found new collision sample: 317/500
# Found new collision sample: 318/500
# Found new collision sample: 319/500
# Found new collision sample: 320/500
# Found new collision sample: 321/500
# Found new collision sample: 322/500
# Attempt 4500: Found 322 collision and 500 no-collision samples
# Found new collision sample: 323/500
# Found new collision sample: 324/500
# Attempt 4600: Found 324 collision and 500 no-collision samples
# Found new collision sample: 325/500
# Found new collision sample: 326/500
# Found new collision sample: 327/500
# Attempt 4700: Found 327 collision and 500 no-collision samples
# Found new collision sample: 328/500
# Found new collision sample: 329/500
# Found new collision sample: 330/500
# Found new collision sample: 331/500
# Found new collision sample: 332/500
# Found new collision sample: 333/500
# Found new collision sample: 334/500
# Attempt 4800: Found 334 collision and 500 no-collision samples
# Found new collision sample: 335/500
# Found new collision sample: 336/500
# Found new collision sample: 337/500
# Found new collision sample: 338/500
# Attempt 4900: Found 338 collision and 500 no-collision samples
# Found new collision sample: 339/500
# Found new collision sample: 340/500
# Found new collision sample: 341/500
# Attempt 5000: Found 341 collision and 500 no-collision samples
# Found new collision sample: 342/500
# Found new collision sample: 343/500
# Found new collision sample: 344/500
# Attempt 5100: Found 344 collision and 500 no-collision samples
# Found new collision sample: 345/500
# Found new collision sample: 346/500
# Attempt 5200: Found 346 collision and 500 no-collision samples
# Found new collision sample: 347/500
# Found new collision sample: 348/500
# Attempt 5300: Found 348 collision and 500 no-collision samples
# Found new collision sample: 349/500
# Found new collision sample: 350/500
# Found new collision sample: 351/500
# Attempt 5400: Found 351 collision and 500 no-collision samples
# Found new collision sample: 352/500
# Found new collision sample: 353/500
# Attempt 5500: Found 353 collision and 500 no-collision samples
# Found new collision sample: 354/500
# Found new collision sample: 355/500
# Attempt 5600: Found 355 collision and 500 no-collision samples
# Found new collision sample: 356/500
# Attempt 5700: Found 356 collision and 500 no-collision samples
# Found new collision sample: 357/500
# Found new collision sample: 358/500
# Found new collision sample: 359/500
# Found new collision sample: 360/500
# Found new collision sample: 361/500
# Attempt 5800: Found 361 collision and 500 no-collision samples
# Found new collision sample: 362/500
# Attempt 5900: Found 362 collision and 500 no-collision samples
# Found new collision sample: 363/500
# Found new collision sample: 364/500
# Found new collision sample: 365/500
# Found new collision sample: 366/500
# Found new collision sample: 367/500
# Attempt 6000: Found 367 collision and 500 no-collision samples
# Found new collision sample: 368/500
# Found new collision sample: 369/500
# Attempt 6100: Found 369 collision and 500 no-collision samples
# Found new collision sample: 370/500
# Found new collision sample: 371/500
# Attempt 6200: Found 371 collision and 500 no-collision samples
# Attempt 6300: Found 371 collision and 500 no-collision samples
# Found new collision sample: 372/500
# Found new collision sample: 373/500
# Attempt 6400: Found 373 collision and 500 no-collision samples
# Found new collision sample: 374/500
# Found new collision sample: 375/500
# Attempt 6500: Found 375 collision and 500 no-collision samples
# Found new collision sample: 376/500
# Found new collision sample: 377/500
# Found new collision sample: 378/500
# Attempt 6600: Found 378 collision and 500 no-collision samples
# Found new collision sample: 379/500
# Found new collision sample: 380/500
# Found new collision sample: 381/500
# Attempt 6700: Found 381 collision and 500 no-collision samples
# Found new collision sample: 382/500
# Found new collision sample: 383/500
# Found new collision sample: 384/500
# Found new collision sample: 385/500
# Found new collision sample: 386/500
# Found new collision sample: 387/500
# Attempt 6800: Found 387 collision and 500 no-collision samples
# Found new collision sample: 388/500
# Attempt 6900: Found 388 collision and 500 no-collision samples
# Found new collision sample: 389/500
# Attempt 7000: Found 389 collision and 500 no-collision samples
# Attempt 7100: Found 389 collision and 500 no-collision samples
# Attempt 7200: Found 389 collision and 500 no-collision samples
# Found new collision sample: 390/500
# Found new collision sample: 391/500
# Found new collision sample: 392/500
# Attempt 7300: Found 392 collision and 500 no-collision samples
# Found new collision sample: 393/500
# Found new collision sample: 394/500
# Found new collision sample: 395/500
# Found new collision sample: 396/500
# Attempt 7400: Found 396 collision and 500 no-collision samples
# Found new collision sample: 397/500
# Attempt 7500: Found 397 collision and 500 no-collision samples
# Found new collision sample: 398/500
# Attempt 7600: Found 398 collision and 500 no-collision samples
# Found new collision sample: 399/500
# Found new collision sample: 400/500
# Attempt 7700: Found 400 collision and 500 no-collision samples
# Found new collision sample: 401/500
# Found new collision sample: 402/500
# Found new collision sample: 403/500
# Found new collision sample: 404/500
# Found new collision sample: 405/500
# Attempt 7800: Found 405 collision and 500 no-collision samples
# Found new collision sample: 406/500
# Found new collision sample: 407/500
# Found new collision sample: 408/500
# Attempt 7900: Found 408 collision and 500 no-collision samples
# Found new collision sample: 409/500
# Attempt 8000: Found 409 collision and 500 no-collision samples
# Found new collision sample: 410/500
# Found new collision sample: 411/500
# Found new collision sample: 412/500
# Found new collision sample: 413/500
# Found new collision sample: 414/500
# Attempt 8100: Found 414 collision and 500 no-collision samples
# Found new collision sample: 415/500
# Attempt 8200: Found 415 collision and 500 no-collision samples
# Found new collision sample: 416/500
# Attempt 8300: Found 416 collision and 500 no-collision samples
# Found new collision sample: 417/500
# Found new collision sample: 418/500
# Found new collision sample: 419/500
# Found new collision sample: 420/500
# Attempt 8400: Found 420 collision and 500 no-collision samples
# Found new collision sample: 421/500
# Attempt 8500: Found 421 collision and 500 no-collision samples
# Found new collision sample: 422/500
# Attempt 8600: Found 422 collision and 500 no-collision samples
# Attempt 8700: Found 422 collision and 500 no-collision samples
# Found new collision sample: 423/500
# Found new collision sample: 424/500
# Found new collision sample: 425/500
# Attempt 8800: Found 425 collision and 500 no-collision samples
# Found new collision sample: 426/500
# Found new collision sample: 427/500
# Attempt 8900: Found 427 collision and 500 no-collision samples
# Attempt 9000: Found 427 collision and 500 no-collision samples
# Found new collision sample: 428/500
# Found new collision sample: 429/500
# Attempt 9100: Found 429 collision and 500 no-collision samples
# Found new collision sample: 430/500
# Found new collision sample: 431/500
# Attempt 9200: Found 431 collision and 500 no-collision samples
# Found new collision sample: 432/500
# Attempt 9300: Found 432 collision and 500 no-collision samples
# Attempt 9400: Found 432 collision and 500 no-collision samples
# Attempt 9500: Found 432 collision and 500 no-collision samples
# Attempt 9600: Found 432 collision and 500 no-collision samples
# Found new collision sample: 433/500
# Attempt 9700: Found 433 collision and 500 no-collision samples
# Attempt 9800: Found 433 collision and 500 no-collision samples
# Found new collision sample: 434/500
# Found new collision sample: 435/500
# Attempt 9900: Found 435 collision and 500 no-collision samples
# Found new collision sample: 436/500
# Attempt 10000: Found 436 collision and 500 no-collision samples
# Found new collision sample: 437/500
# Attempt 10100: Found 437 collision and 500 no-collision samples
# Found new collision sample: 438/500
# Found new collision sample: 439/500
# Found new collision sample: 440/500
# Attempt 10200: Found 440 collision and 500 no-collision samples
# Attempt 10300: Found 440 collision and 500 no-collision samples
# Found new collision sample: 441/500
# Attempt 10400: Found 441 collision and 500 no-collision samples
# Attempt 10500: Found 441 collision and 500 no-collision samples
# Found new collision sample: 442/500
# Attempt 10600: Found 442 collision and 500 no-collision samples
# Attempt 10700: Found 442 collision and 500 no-collision samples
# Found new collision sample: 443/500
# Found new collision sample: 444/500
# Attempt 10800: Found 444 collision and 500 no-collision samples
# Found new collision sample: 445/500
# Found new collision sample: 446/500
# Found new collision sample: 447/500
# Attempt 10900: Found 447 collision and 500 no-collision samples
# Found new collision sample: 448/500
# Attempt 11000: Found 448 collision and 500 no-collision samples
# Found new collision sample: 449/500
# Found new collision sample: 450/500
# Attempt 11100: Found 450 collision and 500 no-collision samples
# Found new collision sample: 451/500
# Attempt 11200: Found 451 collision and 500 no-collision samples
# Attempt 11300: Found 451 collision and 500 no-collision samples
# Attempt 11400: Found 451 collision and 500 no-collision samples
# Found new collision sample: 452/500
# Attempt 11500: Found 452 collision and 500 no-collision samples
# Found new collision sample: 453/500
# Attempt 11600: Found 453 collision and 500 no-collision samples
# Attempt 11700: Found 453 collision and 500 no-collision samples
# Found new collision sample: 454/500
# Attempt 11800: Found 454 collision and 500 no-collision samples
# Attempt 11900: Found 454 collision and 500 no-collision samples
# Found new collision sample: 455/500
# Found new collision sample: 456/500
# Found new collision sample: 457/500
# Attempt 12000: Found 457 collision and 500 no-collision samples
# Found new collision sample: 458/500
# Attempt 12100: Found 458 collision and 500 no-collision samples
# Found new collision sample: 459/500
# Attempt 12200: Found 459 collision and 500 no-collision samples
# Attempt 12300: Found 459 collision and 500 no-collision samples
# Attempt 12400: Found 459 collision and 500 no-collision samples
# Attempt 12500: Found 459 collision and 500 no-collision samples
# Found new collision sample: 460/500
# Found new collision sample: 461/500
# Attempt 12600: Found 461 collision and 500 no-collision samples
# Found new collision sample: 462/500
# Attempt 12700: Found 462 collision and 500 no-collision samples
# Found new collision sample: 463/500
# Found new collision sample: 464/500
# Attempt 12800: Found 464 collision and 500 no-collision samples
# Found new collision sample: 465/500
# Found new collision sample: 466/500
# Attempt 12900: Found 466 collision and 500 no-collision samples
# Found new collision sample: 467/500
# Found new collision sample: 468/500
# Attempt 13000: Found 468 collision and 500 no-collision samples
# Attempt 13100: Found 468 collision and 500 no-collision samples
# Found new collision sample: 469/500
# Attempt 13200: Found 469 collision and 500 no-collision samples
# Attempt 13300: Found 469 collision and 500 no-collision samples
# Found new collision sample: 470/500
# Attempt 13400: Found 470 collision and 500 no-collision samples
# Attempt 13500: Found 470 collision and 500 no-collision samples
# Found new collision sample: 471/500
# Attempt 13600: Found 471 collision and 500 no-collision samples
# Found new collision sample: 472/500
# Found new collision sample: 473/500
# Attempt 13700: Found 473 collision and 500 no-collision samples
# Attempt 13800: Found 473 collision and 500 no-collision samples
# Found new collision sample: 474/500
# Attempt 13900: Found 474 collision and 500 no-collision samples
# Found new collision sample: 475/500
# Attempt 14000: Found 475 collision and 500 no-collision samples
# Attempt 14100: Found 475 collision and 500 no-collision samples
# Found new collision sample: 476/500
# Attempt 14200: Found 476 collision and 500 no-collision samples
# Attempt 14300: Found 476 collision and 500 no-collision samples
# Attempt 14400: Found 476 collision and 500 no-collision samples
# Found new collision sample: 477/500
# Attempt 14500: Found 477 collision and 500 no-collision samples
# Found new collision sample: 478/500
# Attempt 14600: Found 478 collision and 500 no-collision samples
# Attempt 14700: Found 478 collision and 500 no-collision samples
# Attempt 14800: Found 478 collision and 500 no-collision samples
# Found new collision sample: 479/500
# Attempt 14900: Found 479 collision and 500 no-collision samples
# Found new collision sample: 480/500
# Found new collision sample: 481/500
# Attempt 15000: Found 481 collision and 500 no-collision samples
# Attempt 15100: Found 481 collision and 500 no-collision samples
# Attempt 15200: Found 481 collision and 500 no-collision samples
# Found new collision sample: 482/500
# Attempt 15300: Found 482 collision and 500 no-collision samples
# Attempt 15400: Found 482 collision and 500 no-collision samples
# Found new collision sample: 483/500
# Attempt 15500: Found 483 collision and 500 no-collision samples
# Attempt 15600: Found 483 collision and 500 no-collision samples
# Found new collision sample: 484/500
# Attempt 15700: Found 484 collision and 500 no-collision samples
# Found new collision sample: 485/500
# Attempt 15800: Found 485 collision and 500 no-collision samples
# Attempt 15900: Found 485 collision and 500 no-collision samples
# Attempt 16000: Found 485 collision and 500 no-collision samples
# Found new collision sample: 486/500
# Attempt 16100: Found 486 collision and 500 no-collision samples
# Attempt 16200: Found 486 collision and 500 no-collision samples
# Attempt 16300: Found 486 collision and 500 no-collision samples
# Attempt 16400: Found 486 collision and 500 no-collision samples
# Attempt 16500: Found 486 collision and 500 no-collision samples
# Attempt 16600: Found 486 collision and 500 no-collision samples
# Attempt 16700: Found 486 collision and 500 no-collision samples
# Attempt 16800: Found 486 collision and 500 no-collision samples
# Attempt 16900: Found 486 collision and 500 no-collision samples
# Attempt 17000: Found 486 collision and 500 no-collision samples
# Found new collision sample: 487/500
# Found new collision sample: 488/500
# Attempt 17100: Found 488 collision and 500 no-collision samples
# Attempt 17200: Found 488 collision and 500 no-collision samples
# Attempt 17300: Found 488 collision and 500 no-collision samples
# Attempt 17400: Found 488 collision and 500 no-collision samples
# Found new collision sample: 489/500
# Attempt 17500: Found 489 collision and 500 no-collision samples
# Found new collision sample: 490/500
# Attempt 17600: Found 490 collision and 500 no-collision samples
# Attempt 17700: Found 490 collision and 500 no-collision samples
# Found new collision sample: 491/500
# Attempt 17800: Found 491 collision and 500 no-collision samples
# Found new collision sample: 492/500
# Found new collision sample: 493/500
# Found new collision sample: 494/500
# Attempt 17900: Found 494 collision and 500 no-collision samples
# Attempt 18000: Found 494 collision and 500 no-collision samples
# Found new collision sample: 495/500
# Attempt 18100: Found 495 collision and 500 no-collision samples
# Attempt 18200: Found 495 collision and 500 no-collision samples
# Attempt 18300: Found 495 collision and 500 no-collision samples
# Attempt 18400: Found 495 collision and 500 no-collision samples
# Attempt 18500: Found 495 collision and 500 no-collision samples
# Found new collision sample: 496/500
# Found new collision sample: 497/500
# Attempt 18600: Found 497 collision and 500 no-collision samples
# Found new collision sample: 498/500
# Found new collision sample: 499/500
# Attempt 18700: Found 499 collision and 500 no-collision samples
# Attempt 18800: Found 499 collision and 500 no-collision samples
# Attempt 18900: Found 499 collision and 500 no-collision samples
# Found new collision sample: 500/500
# Saving 500 collision samples...
# Saving 500 no-collision samples...
# Dataset generation completed!
